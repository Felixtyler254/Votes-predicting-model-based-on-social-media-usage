# %%
import pandas as pd
felo= pd.read_csv('/content/SOCIALS .csv')
print("Shape of the social_media:",felo.shape)
felo.head(1000)
# Out:
# Shape of the social_media: (149, 12)
#      USER ID  NO OF POSTS  FOLOWERS  FOLLOWING  LIKES  SHARES  COMMENTS  AGE  \
# 0     123434           56       123         12   1232       5       145   18
# 1     123439           63       190         17   1287       8       190   18
# 2     123444           70       257         22   1342      11       235   18
# 3     123449           77       324         27   1397      14       280   18
# 4     123454           84       391         32   1452      17       325   18
# ..       ...          ...       ...        ...    ...     ...       ...  ...
# 144   124154         6203      9771        732   9152     255      6625   41
# 145   124159         6210      9838        737   9207     258      6670   41
# 146   124164         6217      9905        742   9262     261      6715   42
# 147   124169         6224      9972        747   9317     123      6760   42
# 148   124174         6231     10039        752   9372     126      6805   42
#
#      ADDRESS IN P.O BOX  DONATION TO CANDIDATE 1  DONATION TO CANDIDATE 2  \
# 0                  2231                      232                        0
# 1                  2231                        0                      455
# 2                  2231                        0                      353
# 3                  2231                        0                      553
# 4                  2231                        0                      567
# ..                  ...                      ...                      ...
# 144                2343                      567                     4678
# 145                2343                     3673                     4678
# 146                2343                      655                      457
# 147                2343                      454                     4567
# 148                2343                     4666                        0
#
#      VOTE OUTCOME
# 0               1
# 1               2
# 2               2
# 3               2
# 4               2
# ..            ...
# 144             2
# 145             2
# 146             2
# 147             2
# 148             1
#
# [149 rows x 12 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
felo =pd.read_csv('/content/SOCIALS .csv')
x= felo.drop('LIKES', axis =1)
y= felo['VOTE OUTCOME']
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.4, random_state=65)
felo= DecisionTreeClassifier(criterion= 'entropy',random_state=62)
felo.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=62)

# %%
y_prediction= felo.predict(X_test)
print(y_prediction)
# Out:
# [1 1 2 1 2 1 1 1 2 1 1 2 2 2 1 1 1 1 1 2 1 1 2 1 1 1 1 2 1 2 1 2 1 2 2 2 2
#  2 1 1 2 1 2 2 1 1 1 2 1 2 2 1 1 1 1 2 2 2 1 2]

# %%
accuracy = accuracy_score(y_test,y_prediction)
print ('Accuracy:', accuracy)
print(f"Accuracy: {accuracy:.2f}")
report = classification_report(y_test, y_prediction)
print("Classification report:")
print(report)
conf_matrix= confusion_matrix (y_test,y_prediction)
print ("Confusion Matrix")
print(conf_matrix)
# Out:
# Accuracy: 1.0
# Accuracy: 1.00
# Classification report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        34
#            2       1.00      1.00      1.00        26
#
#     accuracy                           1.00        60
#    macro avg       1.00      1.00      1.00        60
# weighted avg       1.00      1.00      1.00        60
#
# Confusion Matrix
# [[34  0]
#  [ 0 26]]

# %%
from sklearn import tree
from sklearn.datasets import load_files, load_iris
import matplotlib.pyplot as plt
iris = load_iris()
plt.figure(figsize=(15,10))
vao = tree.DecisionTreeClassifier()
vao.fit(iris.data, iris.target)
tree.plot_tree(felo, filled=True)
plt.show()

# %%
import joblib
felo = DecisionTreeClassifier(random_state= 62)
felo.fit(X_train, y_train)
joblib.dump(felo, 'decision_tree_model.pkl')
# Out:
# ['decision_tree_model.pkl']

# %%
import joblib
import pandas as pd

loaded_model = joblib.load('/content/decision_tree_model.pkl')

new_data = pd.DataFrame({
    'LIKES': [4882, 2447, 4627, 484, 747, 2632, 4927],
    'AGE': [32, 44, 28, 67, 66, 24, 31],
    'SHARES': [99, 109, 192, 129, 178, 176, 192],
    'COMMENTS': [321, 123, 109, 99, 190, 92, 126],
    'ADDRESS IN P.O BOX': [3432, 4532, 5323, 2442, 5332, 5432, 5643],
    'FOLLOWING': [233, 5567, 6643, 6753, 754, 754, 7456],
    'DONATION TO CANDIDATE 1': [244, 0, 4344, 0, 34, 0, 0],
    'DONATION TO CANDIDATE 2': [0, 2342, 566, 455, 0, 565, 754],
    'FOLOWERS': [233, 454, 554, 643, 89, 0, 343],
    'NO OF POSTS': [23, 434, 43, 553, 65, 754, 0],
    'USER ID': [2333, 5574, 7654, 754, 7743, 7643, 5433],
    'VOTE OUTCOME': [1, 2, 2, 2, 2, 1, 2],
})

X_new_data = new_data.drop('VOTE OUTCOME', axis=1)
vote_outcome_mapping = {1: "VOTED FOR CANDIDATE 1", 2: "VOTED FOR CANDIDATE 2"}

for i, prediction in enumerate(predictions):
    label = vote_outcome_mapping[prediction]
    print(f"Data {i + 1}: predicted Outcome = {label}")
# Out:
# Data 1: predicted Outcome = VOTED FOR CANDIDATE 2
# Data 2: predicted Outcome = VOTED FOR CANDIDATE 2
# Data 3: predicted Outcome = VOTED FOR CANDIDATE 2
# Data 4: predicted Outcome = VOTED FOR CANDIDATE 2
# Data 5: predicted Outcome = VOTED FOR CANDIDATE 2
# Data 6: predicted Outcome = VOTED FOR CANDIDATE 2
# Data 7: predicted Outcome = VOTED FOR CANDIDATE 2
